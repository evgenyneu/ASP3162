# %% [markdown]
# ## Numerical integration with Python

# %% [markdown]
# ### Task 1: writing integrator

# %%
# %pylab
# %load_ext autoreload
# %autoreload 2
# ion()
# %config InlineBackend.figure_format = 'retina'

# %%
import numpy as np
import matplotlib.pyplot as plt
from lane_embden_integrator import LaneEmbdenIntegrator
from euler_integrator import EulerIntegrator

# %%
lane_embden = LaneEmbdenIntegrator(n=3)
x, y = lane_embden.integrate(method=EulerIntegrator, h=0.01)

# %%
figsize = (8,6)  # Size of the plot

# %%
plt.rc('font', size=14)
plt.figure(figsize=figsize)
plt.xlabel(r'Scaled radius, $\xi$')
plt.ylabel(r'Scaled density, $\theta$')
plt.tight_layout()
plt.plot(x, y[:,0], label="Density")

# %% [markdown]
# ### Task 2: Plotting

# %%
from plotter import plot_density_and_its_derivative_lane_embden

# %%
plot_density_and_its_derivative_lane_embden(h=0.1, n=3,
                                            figsize=figsize,
                                            filename="plots/02a_density_vs_radius_h_0.1.pdf")

plot_density_and_its_derivative_lane_embden(h=0.01, n=3,
                                            figsize=figsize,
                                            filename="plots/02a_density_vs_radius_h_0.01.pdf")

plot_density_and_its_derivative_lane_embden(h=0.001, n=3,
                                            figsize=figsize,
                                            filename="plots/02a_density_vs_radius_h_0.001.pdf")
# Out:
# /Users/evgenii/Google Drive/Monash/ASP3162_comp/Labs/code/10_integration_python/plotter.py:64: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /Users/evgenii/Google Drive/Monash/ASP3162_comp/Labs/code/10_integration_python/plotter.py:64: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /Users/evgenii/Google Drive/Monash/ASP3162_comp/Labs/code/10_integration_python/plotter.py:64: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
