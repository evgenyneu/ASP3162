# %% [markdown]
# ## Using Python classes to plot data

# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %%
import plot
import matplotlib.pyplot as plt

# %% [markdown]
# Load all the data files

# %%
d = plot.DataSet('data/results_')

# %% [markdown]
# Create plotting object

# %%
p = plot.Plot2D(d)

# %% [markdown]
# Make the plot

# %%
p.plot(figsize=(12,7), filename="velocities.pdf")
